# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Before running this, please make sure to install the required packages:
# !pip install pytorch-ignite
# !pip install yacs
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu128

# %%
# !apt-get update > /dev/null
# !apt-get install -y build-essential > /dev/null
# !git clone https://github.com/NVIDIA/apex /content/apex_install_temp > /dev/null
# %cd /content/apex_install_temp
# !pip install -v --disable-pip-version-check --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./
# %cd ..
# !rm -rf /content/apex_install_temp

# %%
# !python train.py --cfg ./configs/SYSU.yml
# Out:
# CfgNode({'prefix': 'SYSU', 'sample_method': 'identity_random', 'batch_size': 32, 'p_size': 4, 'k_size': 8, 'classification': True, 'triplet': True, 'center_cluster': False, 'center': False, 'sm_kl': True, 'bg_kl': True, 'IP': True, 'decompose': True, 'fb_dt': False, 'distalign': True, 'margin': 1.3, 'weight_KL': 2.5, 'weight_sid': 0.5, 'weight_sep': 0.5, 'update_rate': 0.2, 'optimizer': 'adam', 'lr': 0.00035, 'wd': 0.005, 'lr_step': [55, 95], 'fp16': True, 'num_epoch': 160, 'dataset': 'sysu', 'image_size': (384, 144), 'random_flip': True, 'random_crop': True, 'random_erase': True, 'color_jitter': False, 'padding': 10, 'drop_last_stride': True, 'pattern_attention': False, 'modality_attention': 0, 'mutual_learning': False, 'rerank': False, 'num_parts': 6, 'eval_interval': 5, 'start_eval': 5, 'log_period': 150, 'resume': '', 'num_id': 395, 'num_cam': 6, 'data_root': './dataset/SYSU-MM01'})
# ...
